# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import LabelEncoder

# %%
pd.set_option('display.max_columns',None)

# %%
smartphones = pd.read_csv('EDA_smartphones.csv')

# %%
df = smartphones.copy()

# %%
df.head()
# Out:
#   brand_names  price  rating has_5G ChipSet Processor_Company  \
# 0     oneplus  54999    89.0    Yes     NFC        snapdragon
# 1     oneplus  19989    81.0    Yes    None        snapdragon
# 2     samsung  16499    75.0    Yes    None            exynos
# 3    motorola  14999    81.0    Yes    None        snapdragon
# 4      realme  24999    82.0    Yes    None         dimensity
#
#       Processor_Name Processor_Core  Processor_Speed_in_GHz  RAM_in_GB  \
# 0  Snapdragon 8 Gen2      Octa Core                     3.2         12
# 1     Snapdragon 695      Octa Core                     2.2          6
# 2        Exynos 1330      Octa Core                     2.4          4
# 3    Snapdragon  695      Octa Core                     2.2          6
# 4     Dimensity 1080      Octa Core                     2.6          6
#
#    ROM_in_GB  Battery_Capacity_mAh Supports_Fast_Charging  Display_in_inches  \
# 0        256                5000.0                    Yes               6.70
# 1        128                5000.0                    Yes               6.59
# 2         64                5000.0                    Yes               6.60
# 3        128                5000.0                    Yes               6.55
# 4        128                5000.0                    Yes               6.70
#
#    Display_Refresh_Rate  Number_of_Rear_Camera  Number_of_Front_Camera  \
# 0                   120                      3                       1
# 1                   120                      3                       1
# 2                    90                      3                       1
# 3                   120                      3                       1
# 4                   120                      3                       1
#
#    MP_of_Rear  MP_of_Front  Memory_Card_Supported_GB OS_Category OS_Version
# 0        50.0         16.0                      1000     Android         13
# 1        64.0         16.0                      1000     Android         12
# 2        50.0         13.0                      1000     Android         13
# 3        50.0         16.0                      1000     Android         12
# 4       108.0         16.0                      1000     Android         13

# %%
df.drop(columns='Unnamed: 0',inplace=True)

# %%
df.head()
# Out:
#   brand_names                      model  price  rating has_5G ChipSet  \
# 0     oneplus              OnePlus 11 5G  54999    89.0    Yes     NFC
# 1     oneplus  OnePlus Nord CE 2 Lite 5G  19989    81.0    Yes    None
# 2     samsung      Samsung Galaxy A14 5G  16499    75.0    Yes    None
# 3    motorola       Motorola Moto G62 5G  14999    81.0    Yes    None
# 4      realme         Realme 10 Pro Plus  24999    82.0    Yes    None
#
#   Processor_Company     Processor_Name Processor_Core  Processor_Speed_in_GHz  \
# 0        snapdragon  Snapdragon 8 Gen2      Octa Core                     3.2
# 1        snapdragon     Snapdragon 695      Octa Core                     2.2
# 2            exynos        Exynos 1330      Octa Core                     2.4
# 3        snapdragon    Snapdragon  695      Octa Core                     2.2
# 4         dimensity     Dimensity 1080      Octa Core                     2.6
#
#    ...  Supports_Fast_Charging  Display_in_inches  Display_Refresh_Rate  \
# 0  ...                     Yes               6.70                   120
# 1  ...                     Yes               6.59                   120
# 2  ...                     Yes               6.60                    90
# 3  ...                     Yes               6.55                   120
# 4  ...                     Yes               6.70                   120
#
#   Number_of_Rear_Camera  Number_of_Front_Camera  MP_of_Rear  MP_of_Front  \
# 0                     3                       1        50.0         16.0
# 1                     3                       1        64.0         16.0
# 2                     3                       1        50.0         13.0
# 3                     3                       1        50.0         16.0
# 4                     3                       1       108.0         16.0
#
#    Memory_Card_Supported_GB  OS_Category  OS_Version
# 0                      1000      Android          13
# 1                      1000      Android          12
# 2                      1000      Android          13
# 3                      1000      Android          12
# 4                      1000      Android          13
#
# [5 rows x 23 columns]

# %%
df.drop(columns='model',inplace=True)

# %%
df.head()
# Out:
#   brand_names  price  rating has_5G ChipSet Processor_Company  \
# 0     oneplus  54999    89.0    Yes     NFC        snapdragon
# 1     oneplus  19989    81.0    Yes    None        snapdragon
# 2     samsung  16499    75.0    Yes    None            exynos
# 3    motorola  14999    81.0    Yes    None        snapdragon
# 4      realme  24999    82.0    Yes    None         dimensity
#
#       Processor_Name Processor_Core  Processor_Speed_in_GHz  RAM_in_GB  \
# 0  Snapdragon 8 Gen2      Octa Core                     3.2         12
# 1     Snapdragon 695      Octa Core                     2.2          6
# 2        Exynos 1330      Octa Core                     2.4          4
# 3    Snapdragon  695      Octa Core                     2.2          6
# 4     Dimensity 1080      Octa Core                     2.6          6
#
#    ROM_in_GB  Battery_Capacity_mAh Supports_Fast_Charging  Display_in_inches  \
# 0        256                5000.0                    Yes               6.70
# 1        128                5000.0                    Yes               6.59
# 2         64                5000.0                    Yes               6.60
# 3        128                5000.0                    Yes               6.55
# 4        128                5000.0                    Yes               6.70
#
#    Display_Refresh_Rate  Number_of_Rear_Camera  Number_of_Front_Camera  \
# 0                   120                      3                       1
# 1                   120                      3                       1
# 2                    90                      3                       1
# 3                   120                      3                       1
# 4                   120                      3                       1
#
#    MP_of_Rear  MP_of_Front  Memory_Card_Supported_GB OS_Category OS_Version
# 0        50.0         16.0                      1000     Android         13
# 1        64.0         16.0                      1000     Android         12
# 2        50.0         13.0                      1000     Android         13
# 3        50.0         16.0                      1000     Android         12
# 4       108.0         16.0                      1000     Android         13

# %%
X = df.drop(columns='price')

# %%
y = df['price']

# %%
X.head()
# Out:
#   brand_names  rating has_5G ChipSet Processor_Company     Processor_Name  \
# 0     oneplus    89.0    Yes     NFC        snapdragon  Snapdragon 8 Gen2
# 1     oneplus    81.0    Yes    None        snapdragon     Snapdragon 695
# 2     samsung    75.0    Yes    None            exynos        Exynos 1330
# 3    motorola    81.0    Yes    None        snapdragon    Snapdragon  695
# 4      realme    82.0    Yes    None         dimensity     Dimensity 1080
#
#   Processor_Core  Processor_Speed_in_GHz  RAM_in_GB  ROM_in_GB  \
# 0      Octa Core                     3.2         12        256
# 1      Octa Core                     2.2          6        128
# 2      Octa Core                     2.4          4         64
# 3      Octa Core                     2.2          6        128
# 4      Octa Core                     2.6          6        128
#
#    Battery_Capacity_mAh Supports_Fast_Charging  Display_in_inches  \
# 0                5000.0                    Yes               6.70
# 1                5000.0                    Yes               6.59
# 2                5000.0                    Yes               6.60
# 3                5000.0                    Yes               6.55
# 4                5000.0                    Yes               6.70
#
#    Display_Refresh_Rate  Number_of_Rear_Camera  Number_of_Front_Camera  \
# 0                   120                      3                       1
# 1                   120                      3                       1
# 2                    90                      3                       1
# 3                   120                      3                       1
# 4                   120                      3                       1
#
#    MP_of_Rear  MP_of_Front  Memory_Card_Supported_GB OS_Category  OS_Version
# 0        50.0         16.0                      1000     Android        13.0
# 1        64.0         16.0                      1000     Android        12.0
# 2        50.0         13.0                      1000     Android        13.0
# 3        50.0         16.0                      1000     Android        12.0
# 4       108.0         16.0                      1000     Android        13.0

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.2,random_state=2)

# %%
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.pipeline import Pipeline
from sklearn.linear_model import LogisticRegression

# %%
X.head()
# Out:
#   brand_names  rating has_5G ChipSet Processor_Company     Processor_Name  \
# 0     oneplus    89.0    Yes     NFC        snapdragon  Snapdragon 8 Gen2
# 1     oneplus    81.0    Yes    None        snapdragon     Snapdragon 695
# 2     samsung    75.0    Yes    None            exynos        Exynos 1330
# 3    motorola    81.0    Yes    None        snapdragon    Snapdragon  695
# 4      realme    82.0    Yes    None         dimensity     Dimensity 1080
#
#   Processor_Core  Processor_Speed_in_GHz  RAM_in_GB  ROM_in_GB  \
# 0      Octa Core                     3.2         12        256
# 1      Octa Core                     2.2          6        128
# 2      Octa Core                     2.4          4         64
# 3      Octa Core                     2.2          6        128
# 4      Octa Core                     2.6          6        128
#
#    Battery_Capacity_mAh Supports_Fast_Charging  Display_in_inches  \
# 0                5000.0                    Yes               6.70
# 1                5000.0                    Yes               6.59
# 2                5000.0                    Yes               6.60
# 3                5000.0                    Yes               6.55
# 4                5000.0                    Yes               6.70
#
#    Display_Refresh_Rate  Number_of_Rear_Camera  Number_of_Front_Camera  \
# 0                   120                      3                       1
# 1                   120                      3                       1
# 2                    90                      3                       1
# 3                   120                      3                       1
# 4                   120                      3                       1
#
#    MP_of_Rear  MP_of_Front  Memory_Card_Supported_GB OS_Category  OS_Version
# 0        50.0         16.0                      1000     Android        13.0
# 1        64.0         16.0                      1000     Android        12.0
# 2        50.0         13.0                      1000     Android        13.0
# 3        50.0         16.0                      1000     Android        12.0
# 4       108.0         16.0                      1000     Android        13.0

# %%
X.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 951 entries, 0 to 953
# Data columns (total 21 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   brand_names               951 non-null    object
#  1   rating                    951 non-null    float64
#  2   has_5G                    951 non-null    object
#  3   ChipSet                   951 non-null    object
#  4   Processor_Company         951 non-null    object
#  5   Processor_Name            951 non-null    object
#  6   Processor_Core            951 non-null    object
#  7   Processor_Speed_in_GHz    951 non-null    float64
#  8   RAM_in_GB                 951 non-null    int64
#  9   ROM_in_GB                 951 non-null    int64
#  10  Battery_Capacity_mAh      951 non-null    float64
#  11  Supports_Fast_Charging    951 non-null    object
#  12  Display_in_inches         951 non-null    float64
#  13  Display_Refresh_Rate      951 non-null    int64
#  14  Number_of_Rear_Camera     951 non-null    int64
#  15  Number_of_Front_Camera    951 non-null    int64
#  16  MP_of_Rear                951 non-null    float64
#  17  MP_of_Front               951 non-null    float64
#  18  Memory_Card_Supported_GB  951 non-null    int64
#  19  OS_Category               951 non-null    object
#  20  OS_Version                951 non-null    float64
# dtypes: float64(7), int64(6), object(8)
# memory usage: 163.5+ KB

# %%
step1 = ColumnTransformer(transformers=[('cols',
                                        OneHotEncoder(sparse_output=False,drop='first',handle_unknown='ignore')
                                         ,[0,2,3,4,5,6,11,19])],
                         remainder='passthrough')
step2 = LinearRegression()

pipe = Pipeline([
    ('step1',step1),
    ('step2',step2)
])
pipe.fit(X_train,y_train)
y_pred = pipe.predict(X_test)

accuracy = pipe.score(X_test,y_test)
# Out:
# C:\Users\Mangukiya Ansh\anaconda3\Lib\site-packages\sklearn\preprocessing\_encoders.py:227: UserWarning: Found unknown categories in columns [0, 4] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# C:\Users\Mangukiya Ansh\anaconda3\Lib\site-packages\sklearn\preprocessing\_encoders.py:227: UserWarning: Found unknown categories in columns [0, 4] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(

# %%
print('Accuracy of the Model is:- ',accuracy*100)
# Out:
# Accuracy of the Model is:-  82.85771306628023

# %%
from sklearn.metrics import mean_absolute_error

# %%
mse = mean_absolute_error(y_pred,y_test)

# %%
print('Mean Absolute Error is :- ',mse)
# Out:
# Mean Absolute Error is :-  7372.136411600002

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 951 entries, 0 to 953
# Data columns (total 22 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   brand_names               951 non-null    object
#  1   price                     951 non-null    int64
#  2   rating                    951 non-null    float64
#  3   has_5G                    951 non-null    object
#  4   ChipSet                   951 non-null    object
#  5   Processor_Company         951 non-null    object
#  6   Processor_Name            951 non-null    object
#  7   Processor_Core            951 non-null    object
#  8   Processor_Speed_in_GHz    951 non-null    float64
#  9   RAM_in_GB                 951 non-null    int64
#  10  ROM_in_GB                 951 non-null    int64
#  11  Battery_Capacity_mAh      951 non-null    float64
#  12  Supports_Fast_Charging    951 non-null    object
#  13  Display_in_inches         951 non-null    float64
#  14  Display_Refresh_Rate      951 non-null    int64
#  15  Number_of_Rear_Camera     951 non-null    int64
#  16  Number_of_Front_Camera    951 non-null    int64
#  17  MP_of_Rear                951 non-null    float64
#  18  MP_of_Front               951 non-null    float64
#  19  Memory_Card_Supported_GB  951 non-null    int64
#  20  OS_Category               951 non-null    object
#  21  OS_Version                951 non-null    float64
# dtypes: float64(7), int64(7), object(8)
# memory usage: 170.9+ KB

# %%
smartphones.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 954 entries, 0 to 953
# Data columns (total 24 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Unnamed: 0                954 non-null    int64
#  1   brand_names               954 non-null    object
#  2   model                     954 non-null    object
#  3   price                     954 non-null    int64
#  4   rating                    954 non-null    float64
#  5   has_5G                    954 non-null    object
#  6   ChipSet                   954 non-null    object
#  7   Processor_Company         954 non-null    object
#  8   Processor_Name            954 non-null    object
#  9   Processor_Core            954 non-null    object
#  10  Processor_Speed_in_GHz    954 non-null    float64
#  11  RAM_in_GB                 954 non-null    int64
#  12  ROM_in_GB                 954 non-null    int64
#  13  Battery_Capacity_mAh      954 non-null    float64
#  14  Supports_Fast_Charging    954 non-null    object
#  15  Display_in_inches         954 non-null    float64
#  16  Display_Refresh_Rate      954 non-null    int64
#  17  Number_of_Rear_Camera     954 non-null    int64
#  18  Number_of_Front_Camera    954 non-null    int64
#  19  MP_of_Rear                954 non-null    float64
#  20  MP_of_Front               954 non-null    float64
#  21  Memory_Card_Supported_GB  954 non-null    int64
#  22  OS_Category               954 non-null    object
#  23  OS_Version                954 non-null    object
# dtypes: float64(6), int64(8), object(10)
# memory usage: 179.0+ KB

# %%
df.to_csv('final_smartphones.csv')

# %%
pipe
# Out:
# Pipeline(steps=[('step1',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('cols',
#                                                   OneHotEncoder(drop='first',
#                                                                 handle_unknown='ignore',
#                                                                 sparse_output=False),
#                                                   [0, 2, 3, 4, 5, 6, 11,
#                                                    19])])),
#                 ('step2', LinearRegression())])

# %%
df.sample()
# Out:
#     brand_names  price  rating has_5G ChipSet Processor_Company  \
# 209        vivo  39999    86.0    Yes    None         dimensity
#
#      Processor_Name Processor_Core  Processor_Speed_in_GHz  RAM_in_GB  \
# 209  Dimensity 1300      Octa Core                     3.0         12
#
#      ROM_in_GB  Battery_Capacity_mAh Supports_Fast_Charging  \
# 209        256                4830.0                    Yes
#
#      Display_in_inches  Display_Refresh_Rate  Number_of_Rear_Camera  \
# 209               6.56                   120                      3
#
#      Number_of_Front_Camera  MP_of_Rear  MP_of_Front  \
# 209                       1        64.0         32.0
#
#      Memory_Card_Supported_GB OS_Category  OS_Version
# 209                      1000     Android        12.0

# %%
X.head()
# Out:
#   brand_names  rating has_5G ChipSet Processor_Company     Processor_Name  \
# 0     oneplus    89.0    Yes     NFC        snapdragon  Snapdragon 8 Gen2
# 1     oneplus    81.0    Yes    None        snapdragon     Snapdragon 695
# 2     samsung    75.0    Yes    None            exynos        Exynos 1330
# 3    motorola    81.0    Yes    None        snapdragon    Snapdragon  695
# 4      realme    82.0    Yes    None         dimensity     Dimensity 1080
#
#   Processor_Core  Processor_Speed_in_GHz  RAM_in_GB  ROM_in_GB  \
# 0      Octa Core                     3.2         12        256
# 1      Octa Core                     2.2          6        128
# 2      Octa Core                     2.4          4         64
# 3      Octa Core                     2.2          6        128
# 4      Octa Core                     2.6          6        128
#
#    Battery_Capacity_mAh Supports_Fast_Charging  Display_in_inches  \
# 0                5000.0                    Yes               6.70
# 1                5000.0                    Yes               6.59
# 2                5000.0                    Yes               6.60
# 3                5000.0                    Yes               6.55
# 4                5000.0                    Yes               6.70
#
#    Display_Refresh_Rate  Number_of_Rear_Camera  Number_of_Front_Camera  \
# 0                   120                      3                       1
# 1                   120                      3                       1
# 2                    90                      3                       1
# 3                   120                      3                       1
# 4                   120                      3                       1
#
#    MP_of_Rear  MP_of_Front  Memory_Card_Supported_GB OS_Category  OS_Version
# 0        50.0         16.0                      1000     Android        13.0
# 1        64.0         16.0                      1000     Android        12.0
# 2        50.0         13.0                      1000     Android        13.0
# 3        50.0         16.0                      1000     Android        12.0
# 4       108.0         16.0                      1000     Android        13.0

# %%
arr = [['vivo',88.0,'No','NFC','snapdragon','Snapdragon 8 Gen2','Octa Core',3.4,18,128,5000.0,'Yes',6.70,120,3,1,108.0,64.0,1000,'Android',13.0
        ]]
Query = np.array(arr)
Query.size
# Out:
# 21

# %%
X.shape
# Out:
# (951, 21)

# %%
Query.reshape(1,21)
# Out:
# array([['vivo', '88.0', 'No', 'NFC', 'snapdragon', 'Snapdragon 8 Gen2',
#         'Octa Core', '3.4', '18', '128', '5000.0', 'Yes', '6.7', '120',
#         '3', '1', '108.0', '64.0', '1000', 'Android', '13.0']],
#       dtype='<U32')

# %%
pipe.predict(arr)
# Out:
# C:\Users\Mangukiya Ansh\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but OneHotEncoder was fitted with feature names
#   warnings.warn(
# C:\Users\Mangukiya Ansh\anaconda3\Lib\site-packages\sklearn\preprocessing\_encoders.py:227: UserWarning: Found unknown categories in columns [2] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# array([50485.23514155])

# %%
import pickle

pickle.dump(df,open('df.pkl','wb'))
pickle.dump(pipe,open('pipe.pkl','wb'))

# %%
df.head()
# Out:
#   brand_names  price  rating has_5G ChipSet Processor_Company  \
# 0     oneplus  54999    89.0    Yes     NFC        snapdragon
# 1     oneplus  19989    81.0    Yes    None        snapdragon
# 2     samsung  16499    75.0    Yes    None            exynos
# 3    motorola  14999    81.0    Yes    None        snapdragon
# 4      realme  24999    82.0    Yes    None         dimensity
#
#       Processor_Name Processor_Core  Processor_Speed_in_GHz  RAM_in_GB  \
# 0  Snapdragon 8 Gen2      Octa Core                     3.2         12
# 1     Snapdragon 695      Octa Core                     2.2          6
# 2        Exynos 1330      Octa Core                     2.4          4
# 3    Snapdragon  695      Octa Core                     2.2          6
# 4     Dimensity 1080      Octa Core                     2.6          6
#
#    ROM_in_GB  Battery_Capacity_mAh Supports_Fast_Charging  Display_in_inches  \
# 0        256                5000.0                    Yes               6.70
# 1        128                5000.0                    Yes               6.59
# 2         64                5000.0                    Yes               6.60
# 3        128                5000.0                    Yes               6.55
# 4        128                5000.0                    Yes               6.70
#
#    Display_Refresh_Rate  Number_of_Rear_Camera  Number_of_Front_Camera  \
# 0                   120                      3                       1
# 1                   120                      3                       1
# 2                    90                      3                       1
# 3                   120                      3                       1
# 4                   120                      3                       1
#
#    MP_of_Rear  MP_of_Front  Memory_Card_Supported_GB OS_Category  OS_Version
# 0        50.0         16.0                      1000     Android        13.0
# 1        64.0         16.0                      1000     Android        12.0
# 2        50.0         13.0                      1000     Android        13.0
# 3        50.0         16.0                      1000     Android        12.0
# 4       108.0         16.0                      1000     Android        13.0

# %%
df.ChipSet.value_counts()
# Out:
# ChipSet
#  None          473
#  NFC           322
#  IR Blaster    156
# Name: count, dtype: int64

# %%
df.shape
# Out:
# (951, 22)

# %%
df.MP_of_Front.describe()
# Out:
# count    951.000000
# mean      16.727647
# std       10.933980
# min        0.300000
# 25%        8.000000
# 50%       16.000000
# 75%       16.558402
# max       60.000000
# Name: MP_of_Front, dtype: float64

# %%
df.Display_in_inches.describe()
# Out:
# count    951.000000
# mean       6.535801
# std        0.356591
# min        2.700000
# 25%        6.500000
# 50%        6.580000
# 75%        6.670000
# max        8.030000
# Name: Display_in_inches, dtype: float64

# %%
df.OS_Version.value_counts()
# Out:
# OS_Version
# 12.0    412
# 11.0    265
# 13.0     93
# 10.0     87
# 9.0      28
# 15.0     15
# 16.0     15
# 8.1       9
# 14.0      8
# 2.0       5
# 8.0       4
# 5.1       3
# 12.1      2
# 6.0       2
# 12.3      1
# 17.0      1
# 7.1       1
# Name: count, dtype: int64

# %%
smartphones.sample()
# Out:
#      Unnamed: 0 brand_names                                 model  price  \
# 447         448     samsung  Samsung Galaxy M04 (4GB RAM + 128GB)   9499
#
#      rating has_5G ChipSet Processor_Company Processor_Name Processor_Core  \
# 447    68.0     No    None             helio      Helio P35      Octa Core
#
#      Processor_Speed_in_GHz  RAM_in_GB  ROM_in_GB  Battery_Capacity_mAh  \
# 447                     2.3          4        128                5000.0
#
#     Supports_Fast_Charging  Display_in_inches  Display_Refresh_Rate  \
# 447                    Yes                6.5                    60
#
#      Number_of_Rear_Camera  Number_of_Front_Camera  MP_of_Rear  MP_of_Front  \
# 447                      2                       1        13.0          5.0
#
#      Memory_Card_Supported_GB OS_Category OS_Version
# 447                      1000     Android         12

# %%
# pipe1 for MLR


step1 = ColumnTransformer(transformers=[('cols',
                                        OneHotEncoder(sparse_output=False,drop='first',handle_unknown='ignore')
                                         ,[0,2,3,4,5,6,11,19])],
                         remainder='passthrough')
step2 = LinearRegression()

pipe1 = Pipeline([
    ('step1',step1),
    ('step2',step2)
])
pipe1.fit(X_train,y_train)
y_pred_1 = pipe1.predict(X_test)
# Out:
# C:\Users\Mangukiya Ansh\anaconda3\Lib\site-packages\sklearn\preprocessing\_encoders.py:227: UserWarning: Found unknown categories in columns [0, 4] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(

# %%
# Pipe2 for Random Forest Regressor


from sklearn.ensemble import RandomForestRegressor

step1 = ColumnTransformer(transformers=[('cols',
                                        OneHotEncoder(sparse_output=False,drop='first',handle_unknown='ignore')
                                         ,[0,2,3,4,5,6,11,19])],
                         remainder='passthrough')
step2 = RandomForestRegressor()

pipe2 = Pipeline([
    ('step1',step1),
    ('step2',step2)
])
pipe2.fit(X_train,y_train)
y_pred_2 = pipe2.predict(X_test)
# Out:
# C:\Users\Mangukiya Ansh\anaconda3\Lib\site-packages\sklearn\preprocessing\_encoders.py:227: UserWarning: Found unknown categories in columns [0, 4] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(

# %%
df.sample()
# Out:
#     brand_names  price  rating has_5G      ChipSet Processor_Company  \
# 951        poco  28990    85.0    Yes   IR Blaster         dimensity
#
#      Processor_Name Processor_Core  Processor_Speed_in_GHz  RAM_in_GB  \
# 951  Dimensity 8100      Octa Core                    2.85          8
#
#      ROM_in_GB  Battery_Capacity_mAh Supports_Fast_Charging  \
# 951        256                5080.0                    Yes
#
#      Display_in_inches  Display_Refresh_Rate  Number_of_Rear_Camera  \
# 951            6.45332                    60                      3
#
#      Number_of_Front_Camera  MP_of_Rear  MP_of_Front  \
# 951                       1        64.0         16.0
#
#      Memory_Card_Supported_GB OS_Category  OS_Version
# 951                      1000     Android        12.0

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, median_absolute_error, r2_score

# %%
mae_1 = mean_absolute_error(y_test, y_pred_1)
mse_1 = mean_squared_error(y_test, y_pred_1)
rmse_1 = mean_squared_error(y_test, y_pred_1, squared=False)
mape_1 = median_absolute_error(y_test, y_pred_1)
r2_1 = r2_score(y_test, y_pred_1)

# %%
mae_2 = mean_absolute_error(y_test, y_pred_2)
mse_2 = mean_squared_error(y_test, y_pred_2)
rmse_2 = mean_squared_error(y_test, y_pred_2, squared=False)
mape_2 = median_absolute_error(y_test, y_pred_2)
r2_2 = r2_score(y_test, y_pred_2)

# %%
print(r2_1)
# Out:
# 0.8285771306628023

# %%
print(r2_2)
# Out:
# 0.9283179107552473

# %%
pipe2
# Out:
# Pipeline(steps=[('step1',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('cols',
#                                                   OneHotEncoder(drop='first',
#                                                                 handle_unknown='ignore',
#                                                                 sparse_output=False),
#                                                   [0, 2, 3, 4, 5, 6, 11,
#                                                    19])])),
#                 ('step2', RandomForestRegressor())])
